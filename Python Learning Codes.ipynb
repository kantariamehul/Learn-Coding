# %%
Frea#comment
'''Multiple
Line
comments'''
INT_VAR=1
FLOAT_VAR=1.5
STRING_VAR="PYTHON" # non mutable, can not be changes once created
print(STRING_VAR)
type(STRING_VAR)
# Out:
# PYTHON
# str

# %%
LIST_VAR=[] # Mutable , can be changed, Mixed Data type
TUPPLE_VAR=() # non-mutable, Can not be modified, Same data type
DICT_VAR={} # Key and value concept, Keys are unique

# %%
LIST_VAR.append(11)
LIST_VAR.append(1.5)
LIST_VAR.append("Hi")
LIST_VAR
# Out:
# [11, 1.5, 'Hi']

# %%
INPUT_VAR=input("Enterv a number:")
print("The entered number is:",INPUT_VAR)
print("Type of input is: ", type(INPUT_VAR))
# Out:
# Enterv a number: 5
# The entered number is: 5
# Type of input is:  <class 'str'>

# %%
INPUT_VAR=int(INPUT_VAR) # convert string/float to integer
FtoI=float(INT_VAR)
ItoF=int(FLOAT_VAR)
STR=str(ItoF)
print("FtoI is ", FtoI, " and ItoF is ", ItoF, ' and STRING', STR)
# Out:
# FtoI is  1.0  and ItoF is  1  and STRING 1

# %%
if (INPUT_VAR >10):
    print("The number is greater then 10")
elif (INPUT_VAR < 10):
    print("The number is less then 10")
else:
    print("The number is 10")
# Out:
# The number is less then 10

# %%
def ADDITION (NUM_1, NUM_2):
    Ans= NUM_1 + NUM_2 
    return Ans
print(ADDITION(ItoF,FtoI))
# Out:
# 2.0

# %%
if __name__ == '__main__':
    print("Entry point of code is original file")
else:
    print("Entry point of code is from IMPORT FILE.py")
# Out:
# Entry point of code is original file

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
for i in LIST_VAR:
    print (i)
# Out:
# 11
# 1.5
# Hi

# %%
import math
print(math.fabs(ItoF))
# Out:
# 1.0

# %%
#Keywords are predefined words and can not be used as variables
"""
Logical: and or not
Loop: for in break continue while
Conditional: if elif else 
Input / Output : print input
Data types: type True False global None
Object oriented programming: def class import return as
Other: assert del except finally from is lambda (???)
     : nonlocal pass raise try with yield (???)
"""
#yeild : used to replace return in funstion and return generator object
#       : next(function_name) can be used to get value inside Generator
#       : Yeild returns the value each time and continue function execution when returns only executed once in the function
#with : used for exception handling and error management
#assert: is used to generate assertion error if condition is false
#      assert x == 0, "x should be non zero for division"
#del : delete any variable,class object or element in list
#    : del X, del X[0], del Car
#try and except : used to handle exception error handling
#     if error is generated in try the execute except block
#    :Some of the common Exception Errors
#     IOError: if the file can’t be opened
#     KeyboardInterrupt: when an unrequired key is pressed by the user
#     ValueError: when built-in function receives a wrong argument
#     EOFError: if End-Of-File is hit without reading any data
#     ImportError: if it is unable to find the module
#raise : stop program execution and raise error
#     raise Exception("Display message")
#     raise TypeError("Display message")
#pass : Do nothing and used to add  atleast one line in if, class, def      
#     if X>B:
#         pass
#nonlocal: nonlocal variables are used in nested functions     
#       : its is nither global nor local
#       : nonlocal VAR1 does not define new local variable in child funstion but use the already defined variable in parent function
#       : def Parent():
#       :     VAR1=0
#       :     def child():
#       :         nonlocal VAR1;
#       :         VAR1 = VAR1 * VAR1
#None : is NULL, X= None so X does not have any value     
#lambda: The function without the name with multiple arguments and one expression
#      : Function_name = lambda arguments: expression --> how to define
#      : Function_name(argunets) --> how to call
#is : used to check two variables represent same obejct or not, not for same values or not     
#     X is Y, CAR is VEHICLE returns True or False
# from and import: Import only specific section from the module     
#      : from datetime import time
#     
#     
#     
#     
#     
#
# Out:
# '\nLogical: and or not\nLoop: for in break continue while\nConditional: if elif else \nInput / Output : print input\nData types: type True False global None\nObject oriented programming: def class import return as\nOther: assert del except finally from is lambda (???)\n     : nonlocal pass raise try with yield (???)\n'

# %%
#read/open a file without with
#Read mode, Can not edit
File1_r=open("Hello.txt","r")
File1_r.close()

#Append mode
File1_a=open("Hello.txt","a")
File1_a.write("Opened in append mode")
File1_a.close()

# write mode, clear all content and start writing
File1_w=open("Hello.txt","w")
File1_w.write("Writen in Write mode")
File1_w.close()

# with try and finally
File1_w=open("Hello.txt","w")
try:
    File1_w.write("With try and finally")
finally:
    File1_w.close()

# %%
#file open using with
with open("Hello.txt","w") as File2_w:
    File2_w.write("Uisng with")
# no need to close the file - Difference

# %%
X=1
Y=1
#Y=0
try:
    print(X/Y)
except ZeroDivisionError:
    print("Value of Y is Zero, so division is not possible")
else:
    print("Division is successfull")
finally:
    print("Process is over")
# Out:
# 1.0
# Division is successfull
# Process is over

# %%
X=10
Y=6
def SUB(A,B):
    return A-B
SUBTRACT = lambda A,B : A-B
print(SUB(X,Y))
print(SUBTRACT(X,Y))
# Out:
# 4
# 4

# %%
#and Return the first false value. If not found return last
print(5 and 0)
print(0 and 5)
print(0 and 5 and 10 and 15)
print(15 and 10 and 5)
# Out:
# 0
# 0
# 0
# 5

# %%
#or Return the first True value. If not found return first
print(5 or 0)
print(0 or 5)
print(0 or 5 or 10 or 15)
print(15 or 10 or 5)
# Out:
# 5
# 5
# 5
# 15

# %%
print(' ' is ' ') # immutable so both ' ' have same memory location
print({} is {}) # Dictionary is mutable so both {} assigned different memory address
# Out:
# True
# False
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Mehul\AppData\Local\Temp/ipykernel_3572/170857929.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print(' ' is ' ')

# %%
#class
class Car:
    Speed=0 # Attributes, Data 
    def Acc(self): # Method
        self.Speed+=5
    def Break(self): # Method
        self.Speed-=5
SUV=Car()
print(SUV.Speed)
SUV.Acc()
print(SUV.Speed)
SUV.Acc()
print(SUV.Speed)
SUV.Break()
print(SUV.Speed)
# Out:
# 0
# 5
# 10
# 5

# %%
# Statements in multiple line can be defined using 
# square brackets [], semi-colon (;)
A=1;B=2
Y=[A,
   B]
print(A,B,Y)
# Out:
# 1 2 [1, 2]

# %%
#Smart methods
A=5
B= A if A>5 else 0
print(A,B)
# Out:
# 5 0

# %%
A,B,C=input("Enter 3 values sepatared by space").split(' ',3)# split(separator, max seperator)
print(A,B,C)
# Out:
# Enter 3 values sepatared by space 1 2 3
# 1 2 3

# %%
x,y= [int(x) for x in input("Enter multiple value: ").split()]
print(x,y)
# Out:
# Enter multiple value:  1 2
# 1 2

# %%
print("Value of A and B are",A,"and",B,sep=" ",end="\n")
# Out:
# Value of A and B are 1 and 2

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df.columns[0]
# Out:
# 'longitude'
